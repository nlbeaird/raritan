# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sio
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
coast = sio.loadmat("../coastlines/MAB_COAST_JOINED.mat",squeeze_me=True, struct_as_record=False);

coastlines_lon = coast['codat'][:,0]

coastlines_lat = coast['codat'][:,1]

# %%
data_crs = ccrs.PlateCarree()
projection = ccrs.Mercator()

fig, ax = plt.subplots(
    figsize=(6.5, 6.5),
    subplot_kw=dict(projection=projection)
)

# ax.set_extent([-74.464228, -74.0, 40.409759, 40.6])
ax.set_extent([-74.769887,-74.193105,39.407994 ,39.650555]) # mullaca

plt.plot(coastlines_lon, coastlines_lat, transform=data_crs)

ax.gridlines()

# %%
data_crs = ccrs.PlateCarree()
projection = ccrs.Mercator()

fig, ax = plt.subplots(
    figsize=(6.5, 6.5),
    subplot_kw=dict(projection=projection)
)

ax.set_extent([-74.464228, -74.175837, 40.409759, 40.552210])

plt.plot(coastlines_lon, coastlines_lat, transform=data_crs)

ax.gridlines()

# %%
data_crs = ccrs.PlateCarree()
projection = ccrs.Mercator()

fig, ax = plt.subplots(
    figsize=(6.5, 6.5),
    subplot_kw=dict(projection=projection)
)

ax.set_extent([-74.464228, -74.0, 40.409759, 40.6])
ax.coastlines(resolution='10m', color='black', linewidth=1)
# Out:
# /Users/beaird/anaconda3/lib/python3.7/site-packages/cartopy/io/__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/10m/physical/ne_10m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
